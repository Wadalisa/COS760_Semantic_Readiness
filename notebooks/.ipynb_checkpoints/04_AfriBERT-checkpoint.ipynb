# %% [markdown]
# # SemRel — AfriBERT Fine-tuning
# **COS 760 Group Project**
# Fine-tunes [xlm-roberta-base](https://huggingface.co/xlm-roberta-base) (a strong multilingual baseline that covers Afrikaans) on the SemRel2024 Afrikaans semantic-relatedness task.
#
# The model is trained as a **regression** head (single sigmoid output scaled to [0, 1]) using MSE loss.
#
# Inputs: cleaned CSVs from `02_preprocessing.ipynb`
# Outputs: `./model_outputs/afribert_best/` — best checkpoint + predictions

# %% [markdown]
# ## 1. Install & Import Dependencies

# %%
# !pip install transformers datasets torch scipy pandas numpy matplotlib tqdm -q

# %%
import os, warnings, random
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
from scipy.stats import spearmanr, pearsonr

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    get_linear_schedule_with_warmup,
)

# ── Reproducibility ──────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

DEVICE      = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
DATA_DIR    = './cleaned_data'
OUTPUT_DIR  = './model_outputs/afribert_best'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── Hyper-parameters ─────────────────────────────────────────────────────────
MODEL_NAME   = 'xlm-roberta-base'   # multilingual; strong Afrikaans coverage
MAX_LEN      = 128
BATCH_SIZE   = 16
EPOCHS       = 5
LR           = 2e-5
WARMUP_RATIO = 0.1
WEIGHT_DECAY = 0.01

print(f'Device: {DEVICE}')
print(f'Model : {MODEL_NAME}')

# %% [markdown]
# ## 2. Load Cleaned Data

# %%
def load_split(lang: str, split: str, data_dir: str = DATA_DIR) -> pd.DataFrame:
    path = os.path.join(data_dir, f'{lang}_{split}.csv')
    if not os.path.exists(path):
        raise FileNotFoundError(
            f'File not found: {path}\nRun 02_preprocessing.ipynb first.'
        )
    return pd.read_csv(path)

train_df = load_split('afr', 'train')
dev_df   = load_split('afr', 'dev')
test_df  = load_split('afr', 'test')

print(f'Train: {len(train_df)} rows')
print(f'Dev  : {len(dev_df)} rows')
print(f'Test : {len(test_df)} rows')
display(train_df.head(3))

# %% [markdown]
# ## 3. Dataset & DataLoader

# %%
class SemRelDataset(Dataset):
    """Tokenises sentence pairs and returns tensors for the transformer."""

    def __init__(self, df: pd.DataFrame, tokenizer, max_len: int):
        self.df        = df.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_len   = max_len

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        enc = self.tokenizer(
            str(row['sentence1']),
            str(row['sentence2']),
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt',
        )
        return {
            'input_ids':      enc['input_ids'].squeeze(0),
            'attention_mask': enc['attention_mask'].squeeze(0),
            'score':          torch.tensor(row['score'], dtype=torch.float),
        }

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

train_ds = SemRelDataset(train_df, tokenizer, MAX_LEN)
dev_ds   = SemRelDataset(dev_df,   tokenizer, MAX_LEN)
test_ds  = SemRelDataset(test_df,  tokenizer, MAX_LEN)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
dev_loader   = DataLoader(dev_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

print(f'Train batches: {len(train_loader)} | Dev batches: {len(dev_loader)} | Test batches: {len(test_loader)}')

# %% [markdown]
# ## 4. Model Definition
# We attach a single-output regression head on top of XLM-RoBERTa's `[CLS]` embedding and apply a **sigmoid** to keep predictions in [0, 1].

# %%
class SemRelRegressor(nn.Module):
    """XLM-RoBERTa with a regression head for semantic relatedness scoring."""

    def __init__(self, model_name: str, dropout: float = 0.1):
        super().__init__()
        self.encoder = AutoModelForSequenceClassification.from_pretrained(
            model_name,
            num_labels=1,
            hidden_dropout_prob=dropout,
            attention_probs_dropout_prob=dropout,
            ignore_mismatched_sizes=True,
        )

    def forward(self, input_ids, attention_mask):
        out = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        # Sigmoid squashes logits to (0, 1) matching the [0, 1] label range
        return torch.sigmoid(out.logits.squeeze(-1))


model = SemRelRegressor(MODEL_NAME).to(DEVICE)
n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Trainable parameters: {n_params:,}')

# %% [markdown]
# ## 5. Optimiser & Scheduler

# %%
criterion = nn.MSELoss()

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=WEIGHT_DECAY,
)

total_steps   = len(train_loader) * EPOCHS
warmup_steps  = int(total_steps * WARMUP_RATIO)

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_steps,
)

print(f'Total steps: {total_steps} | Warmup steps: {warmup_steps}')

# %% [markdown]
# ## 6. Training & Validation Loop

# %%
def evaluate(model, loader, device):
    """Return MSE, Pearson r, Spearman rho on a data split."""
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in loader:
            ids  = batch['input_ids'].to(device)
            mask = batch['attention_mask'].to(device)
            lbls = batch['score'].to(device)
            preds = model(ids, mask)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(lbls.cpu().numpy())

    preds  = np.array(all_preds)
    labels = np.array(all_labels)
    mse     = float(np.mean((preds - labels) ** 2))
    pearson = pearsonr(preds, labels)[0]
    spearman = spearmanr(preds, labels)[0]
    return mse, pearson, spearman

# %%
history = {'train_loss': [], 'dev_mse': [], 'dev_pearson': [], 'dev_spearman': []}
best_spearman = -1.0
best_epoch    = -1

for epoch in range(1, EPOCHS + 1):
    model.train()
    epoch_loss = 0.0

    for batch in tqdm(train_loader, desc=f'Epoch {epoch}/{EPOCHS}', leave=False):
        ids   = batch['input_ids'].to(DEVICE)
        mask  = batch['attention_mask'].to(DEVICE)
        lbls  = batch['score'].to(DEVICE)

        optimizer.zero_grad()
        preds = model(ids, mask)
        loss  = criterion(preds, lbls)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        epoch_loss += loss.item()

    avg_loss = epoch_loss / len(train_loader)
    mse, pear, spear = evaluate(model, dev_loader, DEVICE)
    history['train_loss'].append(avg_loss)
    history['dev_mse'].append(mse)
    history['dev_pearson'].append(pear)
    history['dev_spearman'].append(spear)

    print(f'Epoch {epoch:02d} | Train Loss={avg_loss:.4f} | '
          f'Dev MSE={mse:.4f} | Pearson={pear:.4f} | Spearman={spear:.4f}')

    if spear > best_spearman:
        best_spearman = spear
        best_epoch    = epoch
        torch.save(model.state_dict(), os.path.join(OUTPUT_DIR, 'best_model.pt'))
        print(f'           ↳ New best Spearman — checkpoint saved.')

print(f'\nBest Spearman: {best_spearman:.4f} at epoch {best_epoch}')

# %% [markdown]
# ## 7. Training Curve

# %%
epochs_range = range(1, EPOCHS + 1)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(epochs_range, history['train_loss'], marker='o', color='steelblue')
axes[0].set_title('Train Loss (MSE)')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('MSE')

axes[1].plot(epochs_range, history['dev_pearson'], marker='o', color='coral')
axes[1].set_title('Dev Pearson r')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Pearson r')

axes[2].plot(epochs_range, history['dev_spearman'], marker='o', color='seagreen')
axes[2].set_title('Dev Spearman ρ')
axes[2].set_xlabel('Epoch'); axes[2].set_ylabel('Spearman ρ')

for ax in axes:
    ax.axvline(best_epoch, color='gray', linestyle='--', alpha=0.6, label=f'Best epoch {best_epoch}')
    ax.legend(fontsize=8)

fig.suptitle('AfriBERT (XLM-RoBERTa-base) Training Curves — Afrikaans SemRel', fontsize=13)
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'training_curves.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Test Set Evaluation

# %%
# Load best checkpoint
model.load_state_dict(torch.load(os.path.join(OUTPUT_DIR, 'best_model.pt'), map_location=DEVICE))
model.eval()

# Collect predictions on test set
all_preds, all_labels = [], []
with torch.no_grad():
    for batch in tqdm(test_loader, desc='Test inference'):
        ids  = batch['input_ids'].to(DEVICE)
        mask = batch['attention_mask'].to(DEVICE)
        preds = model(ids, mask)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(batch['score'].numpy())

preds_arr  = np.array(all_preds)
labels_arr = np.array(all_labels)

test_mse      = float(np.mean((preds_arr - labels_arr) ** 2))
test_rmse     = float(np.sqrt(test_mse))
test_pearson  = pearsonr(preds_arr, labels_arr)[0]
test_spearman = spearmanr(preds_arr, labels_arr)[0]

print('─' * 45)
print(f'Test MSE     : {test_mse:.4f}')
print(f'Test RMSE    : {test_rmse:.4f}')
print(f'Test Pearson : {test_pearson:.4f}')
print(f'Test Spearman: {test_spearman:.4f}')
print('─' * 45)

# %% [markdown]
# ## 9. Prediction Analysis & Scatter Plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Scatter: predicted vs actual
axes[0].scatter(labels_arr, preds_arr, alpha=0.3, s=10, color='steelblue')
lims = [0, 1]
axes[0].plot(lims, lims, 'r--', linewidth=1.2, label='Perfect prediction')
axes[0].set_xlabel('Gold score')
axes[0].set_ylabel('Predicted score')
axes[0].set_title(f'AfriBERT — Test Predictions vs Gold\n'
                  f'Spearman={test_spearman:.4f}  Pearson={test_pearson:.4f}')
axes[0].legend()

# Residual histogram
residuals = preds_arr - labels_arr
axes[1].hist(residuals, bins=30, color='steelblue', edgecolor='white', alpha=0.85)
axes[1].axvline(0, color='red', linestyle='--', linewidth=1.2)
axes[1].set_xlabel('Residual (pred − gold)')
axes[1].set_ylabel('Count')
axes[1].set_title('Residual distribution')

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, 'predictions_scatter.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10. Save Predictions

# %%
pred_df = test_df[['sentence1', 'sentence2', 'score']].copy()
pred_df.rename(columns={'score': 'gold_score'}, inplace=True)
pred_df['afribert_pred'] = preds_arr

out_path = os.path.join(OUTPUT_DIR, 'test_predictions.csv')
pred_df.to_csv(out_path, index=False)
print(f'Predictions saved to: {out_path}')
display(pred_df.head(10))

# %% [markdown]
# ## 11. Summary

# %%
summary = {
    'Model':         MODEL_NAME,
    'Max Seq Len':   MAX_LEN,
    'Batch Size':    BATCH_SIZE,
    'Learning Rate': LR,
    'Epochs':        EPOCHS,
    'Best Epoch':    best_epoch,
    'Dev Spearman':  round(best_spearman, 4),
    'Test MSE':      round(test_mse, 4),
    'Test RMSE':     round(test_rmse, 4),
    'Test Pearson':  round(test_pearson, 4),
    'Test Spearman': round(test_spearman, 4),
}

print('AfriBERT Fine-tuning Summary')
print('=' * 40)
for k, v in summary.items():
    print(f'{k:<20}: {v}')
